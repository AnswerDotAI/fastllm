# %% [markdown]
# # Costs
#
# > Provider-agnostic token cost estimation.

# %%
#| default_exp costs

# %% [markdown]
# ## Imports

# %%
#| export
from __future__ import annotations
from dataclasses import dataclass
from typing import Any, Mapping, Optional
from .types import Completion, Delta, Usage

# %%
#| hide
from fastcore.test import *

# %% [markdown]
# ## Purpose And Design
#
# `costs.py` computes cost estimates from normalized usage and caller-supplied pricing.
#
# ### Why this module exists
#
# Pricing changes frequently. Hardcoding provider prices in runtime logic creates maintenance burden and stale estimates.
#
# ### Architectural fit
#
# - Upstream: canonical usage data from `Completion`/`Delta`.
# - Downstream: billing dashboards, budgeting guards, and usage reporting.
#
# ### Key design choices
#
# - Require caller-provided pricing table (`ModelPrice`).
# - Support wildcard-like model resolution and cached-token accounting.
# - Keep strict vs non-strict modes explicit.
#
# ### Reader outcome
#
# After this notebook, you should know how cost is derived and where to plug in live pricing sources later.

# %% [markdown]
# ### `ModelPrice`
#
# Per-million-token pricing for a model.
#
# **Role In This Module**
# - Public symbol in this module API surface.
# - Carries behavior central to this module stage of the pipeline.
#
# **Design Notes**
# - Core fields: `prompt_per_million: float`, `completion_per_million: float`, `cached_prompt_per_million: Optional[float]`, `currency: str`
# - Encapsulates one coherent concept to reduce repeated shape logic elsewhere.
#
# **Connections**
# - In-module dependencies used: primarily local logic.
# - Referenced by modules: none or only via orchestration.
# - Module upstream: `types`.

# %%
#| export
class ModelPrice:
    "Per-million-token pricing for a model."
    prompt_per_million: float
    completion_per_million: float
    cached_prompt_per_million: Optional[float] = None
    currency: str = "USD"

# %% [markdown]
# ### `CostBreakdown`
#
# Computed request cost from usage + model pricing.
#
# **Role In This Module**
# - Public symbol in this module API surface.
# - Carries behavior central to this module stage of the pipeline.
#
# **Design Notes**
# - Core fields: `model: str`, `currency: str`, `prompt_tokens: int`, `completion_tokens: int`, `cached_prompt_tokens: int`, `prompt_cost: float` ...
# - Encapsulates one coherent concept to reduce repeated shape logic elsewhere.
#
# **Connections**
# - In-module dependencies used: primarily local logic.
# - Referenced by modules: none or only via orchestration.
# - Module upstream: `types`.

# %%
#| export
class CostBreakdown:
    "Computed request cost from usage + model pricing."
    model: str
    currency: str
    prompt_tokens: int
    completion_tokens: int
    cached_prompt_tokens: int
    prompt_cost: float
    completion_cost: float
    cached_prompt_cost: float
    total_cost: float

# %% [markdown]
# ### `_to_price`
#
# Coerce a mapping/dataclass into ModelPrice.
#
# **Role In This Module**
# - Internal helper for module composition.
# - Carries behavior central to this module stage of the pipeline.
#
# **Design Notes**
# - Signature: `_to_price(v: Any)`
# - Returns: `ModelPrice`
# - Small helper/function boundary keeps calling layers easier to compose and test.
#
# **Connections**
# - In-module dependencies used: primarily local logic.
# - Referenced by modules: none or only via orchestration.
# - Module upstream: `types`.

# %%
#| export
def _to_price(v: Any) -> ModelPrice:
    "Coerce a mapping/dataclass into ModelPrice."
    if isinstance(v, ModelPrice): return v
    if isinstance(v, Mapping):
        pm = float(v.get("prompt_per_million", v.get("prompt", 0.0)) or 0.0)
        cm = float(v.get("completion_per_million", v.get("completion", 0.0)) or 0.0)
        cpm = v.get("cached_prompt_per_million", v.get("cached_prompt"))
        cpm = None if cpm is None else float(cpm)
        cur = str(v.get("currency", "USD"))
        return ModelPrice(prompt_per_million=pm, completion_per_million=cm,
            cached_prompt_per_million=cpm, currency=cur)
    raise TypeError(f"Unsupported price spec: {type(v).__name__}")

# %% [markdown]
# ### `_cached_prompt_tokens`
#
# Best-effort cached prompt token extraction across provider shapes.
#
# **Role In This Module**
# - Internal helper for module composition.
# - Carries behavior central to this module stage of the pipeline.
#
# **Design Notes**
# - Signature: `_cached_prompt_tokens(raw: Mapping[str, Any])`
# - Returns: `int`
# - Small helper/function boundary keeps calling layers easier to compose and test.
#
# **Connections**
# - In-module dependencies used: primarily local logic.
# - Referenced by modules: none or only via orchestration.
# - Module upstream: `types`.

# %%
#| export
def _cached_prompt_tokens(raw: Mapping[str, Any]) -> int:
    "Best-effort cached prompt token extraction across provider shapes."
    cands = [
        raw.get("cached_input_tokens"),
        raw.get("input_cached_tokens"),
        raw.get("cached_tokens"),
        raw.get("cache_read_input_tokens"),
    ]
    d = raw.get("prompt_tokens_details")
    if isinstance(d, Mapping): cands.append(d.get("cached_tokens"))
    for v in cands:
        if v is None: continue
        try: return max(0, int(v))
        except (TypeError, ValueError):
            continue
    return 0

# %% [markdown]
# ### `_extract_usage`
#
# Extract Usage + optional model from Completion/Delta/Usage/dict.
#
# **Role In This Module**
# - Internal helper for module composition.
# - Carries behavior central to this module stage of the pipeline.
#
# **Design Notes**
# - Signature: `_extract_usage(x: Any)`
# - Returns: `tuple[Usage, Optional[str]]`
# - Small helper/function boundary keeps calling layers easier to compose and test.
#
# **Connections**
# - In-module dependencies used: `types`.
# - Referenced by modules: none or only via orchestration.
# - Module upstream: `types`.

# %%
#| export
def _extract_usage(x: Any) -> tuple[Usage, Optional[str]]:
    "Extract Usage + optional model from Completion/Delta/Usage/dict."
    if isinstance(x, Completion): return x.usage or Usage(), x.model
    if isinstance(x, Delta): return x.usage or Usage(), None
    if isinstance(x, Usage): return x, None
    if isinstance(x, Mapping):
        pt = int(x.get("prompt_tokens", x.get("input_tokens", 0)) or 0)
        ct = int(x.get("completion_tokens", x.get("output_tokens", 0)) or 0)
        tt = int(x.get("total_tokens", pt + ct) or (pt + ct))
        mdl = x.get("model")
        return Usage(prompt_tokens=pt, completion_tokens=ct, total_tokens=tt,
            raw=dict(x)), str(mdl) if mdl is not None else None
    raise TypeError(f"Unsupported usage payload: {type(x).__name__}")

# %% [markdown]
# ### `_resolve_price`
#
# Resolve exact or wildcard (* suffix) model pricing entry.
#
# **Role In This Module**
# - Internal helper for module composition.
# - Carries behavior central to this module stage of the pipeline.
#
# **Design Notes**
# - Signature: `_resolve_price(model: str, prices: Mapping[str, Any])`
# - Returns: `Optional[ModelPrice]`
# - Small helper/function boundary keeps calling layers easier to compose and test.
#
# **Connections**
# - In-module dependencies used: primarily local logic.
# - Referenced by modules: none or only via orchestration.
# - Module upstream: `types`.

# %%
#| export
def _resolve_price(model: str, prices: Mapping[str, Any]) -> Optional[ModelPrice]:
    "Resolve exact or wildcard (* suffix) model pricing entry."
    if model in prices: return _to_price(prices[model])
    for k,v in prices.items():
        if not isinstance(k, str): continue
        if k.endswith("*") and model.startswith(k[:-1]): return _to_price(v)
    return None

# %% [markdown]
# ### `estimate_cost`
#
# Estimates request cost from normalized usage and supplied pricing.
#
# **Why it exists**
# - Runtime pricing should stay configurable rather than hardcoded into the library.
#
# **Design Notes**
# - Handles prompt/completion/cached token accounting.
# - Supports strict and non-strict behavior when pricing info is missing.
#
# **Connections**
# - Consumes canonical usage from `Completion`/`Delta`/`Usage` outputs.

# %%
#| export
def estimate_cost(x: Any, *, model: str = "", prices: Optional[Mapping[str, Any]] = None,
    strict: bool = True) -> CostBreakdown:
    """Estimate token cost for a Completion/Delta/Usage-like object.

    Args:
      x: Completion, Delta, Usage, or usage dict.
      model: Optional model override.
      prices: Model pricing map keyed by exact model or wildcard prefix (e.g. "gpt-4.1*").
      strict: Raise if pricing is missing; if false, return zero-cost breakdown.
    """
    usage, mdl = _extract_usage(x)
    mdl = model or mdl or ""
    tbl = prices or {}
    price = _resolve_price(mdl, tbl) if mdl else None
    if price is None:
        if strict: raise KeyError(f"No pricing found for model: {mdl or '<missing>'}")
        price = ModelPrice(prompt_per_million=0.0, completion_per_million=0.0)

    cached_pt = _cached_prompt_tokens(usage.raw or {})
    cached_pt = min(cached_pt, max(0, usage.prompt_tokens))
    normal_pt = max(0, usage.prompt_tokens - cached_pt)

    prompt_cost = (normal_pt / 1_000_000.0) * price.prompt_per_million
    completion_cost = (max(0, usage.completion_tokens) / 1_000_000.0) * price.completion_per_million
    cached_rate = price.cached_prompt_per_million if price.cached_prompt_per_million is not None else price.prompt_per_million
    cached_prompt_cost = (cached_pt / 1_000_000.0) * cached_rate

    total = prompt_cost + completion_cost + cached_prompt_cost
    return CostBreakdown(
        model=mdl,
        currency=price.currency,
        prompt_tokens=max(0, usage.prompt_tokens),
        completion_tokens=max(0, usage.completion_tokens),
        cached_prompt_tokens=cached_pt,
        prompt_cost=prompt_cost,
        completion_cost=completion_cost,
        cached_prompt_cost=cached_prompt_cost,
        total_cost=total)

# %% [markdown]
# ## Quick Checks

# %%
import fastllm.costs as m
for nm in ['ModelPrice', 'CostBreakdown', 'estimate_cost']: assert hasattr(m, nm), nm
from fastllm.types import Completion, Msg, Part, Usage
from fastllm.costs import estimate_cost, ModelPrice
c = Completion(model='gpt-5-mini', message=Msg(role='assistant', content=[Part(type='text', text='ok')]), usage=Usage(prompt_tokens=1000, completion_tokens=500, total_tokens=1500))
res = estimate_cost(c, prices={'gpt-5-mini': ModelPrice(prompt_per_million=1.0, completion_per_million=2.0)})
assert res.total_cost > 0
